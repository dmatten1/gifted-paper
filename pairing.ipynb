# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/final/test_demo.csv")

# %%
gifted_grades = list(range(4, 9))
matched_dfs = []
match_id_counter = 0
caliper = 0.05

for grade in gifted_grades:
    print(f"\nProcessing grade {grade}...")

    treated_all = df[df['gifted_grade'] == grade].copy()
    controls_all = df[df['gifted_grade'] == 0].copy()

    if treated_all.empty:
        print(f"  Skipping grade {grade}: no treated units.")
        continue

    for lea in treated_all['lea'].unique():
        treated = treated_all[treated_all['lea'] == lea].copy()
        controls = controls_all[controls_all['lea'] == lea].copy()

        if treated.empty or controls.empty:
            continue

        sub_df = pd.concat([treated, controls], axis=0).copy()
        sub_df['treatment'] = (sub_df['gifted_grade'] == grade).astype(int)

        test_cols = [col for col in sub_df.columns if col.startswith(('MA', 'RD'))]
        pre_cols = [col for col in test_cols if int(col.split('0')[1]) < grade]
        dummy_cols = [col for col in sub_df.columns if col.startswith(('sex_', 'ethnic_', 'eds_'))]
        covariates = pre_cols + dummy_cols

        sub_df_clean = sub_df.dropna(subset=covariates, how='any').reset_index(drop=True)

        math_cols = [col for col in pre_cols if col.startswith('MA')]
        reading_cols = [col for col in pre_cols if col.startswith('RD')]

        treated_df = sub_df_clean[sub_df_clean['treatment'] == 1]
        if treated_df.empty:
            continue

        math_min = treated_df[math_cols].min().min()
        reading_min = treated_df[reading_cols].min().min()

        sub_df_clean = sub_df_clean[
            sub_df_clean[math_cols].ge(math_min).all(axis=1) &
            sub_df_clean[reading_cols].ge(reading_min).all(axis=1)
        ]

        if sub_df_clean['treatment'].sum() == 0 or sub_df_clean['treatment'].sum() == len(sub_df_clean):
            continue

        # Prepare covariate matrix
        X = sub_df_clean[covariates].copy()
        for col in X.select_dtypes(exclude='number').columns:
            if X[col].dtype == 'bool':
                X[col] = X[col].astype(int)
            elif X[col].dtype == 'object':
                X[col] = X[col].map({'True': 1, 'False': 0, True: 1, False: 0})
        X = X.fillna(0)

        # Standardize covariates
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)

        # Estimate propensity scores
        ps_model = LogisticRegression(max_iter=5000)
        ps_model.fit(X_scaled, sub_df_clean['treatment'])
        sub_df_clean['pscore'] = ps_model.predict_proba(X_scaled)[:, 1]

        # Track row alignment
        row_index_map = dict(zip(sub_df_clean.index, range(len(sub_df_clean))))

        treated = sub_df_clean[sub_df_clean['treatment'] == 1].copy()
        controls = sub_df_clean[sub_df_clean['treatment'] == 0].copy()

        matched_pairs = []

        for idx_t in treated.index:
            pscore_t = sub_df_clean.at[idx_t, 'pscore']
            pool = controls[np.abs(controls['pscore'] - pscore_t) <= caliper]

            if pool.empty:
                continue

            X_t = X_scaled[row_index_map[idx_t]].reshape(1, -1)
            X_pool = X_scaled[[row_index_map[i] for i in pool.index]]

            nn = NearestNeighbors(n_neighbors=1)
            nn.fit(X_pool)
            _, nn_idx = nn.kneighbors(X_t)

            matched_idx = pool.index[nn_idx[0][0]]
            matched_pairs.append((idx_t, matched_idx))

        if not matched_pairs:
            continue

        match_ids = range(match_id_counter, match_id_counter + len(matched_pairs))
        match_id_counter += len(matched_pairs)

        treated_matches = sub_df_clean.loc[[i for i, _ in matched_pairs]].copy()
        control_matches = sub_df_clean.loc[[j for _, j in matched_pairs]].copy()

        treated_matches['match_id'] = match_ids
        control_matches['match_id'] = match_ids

        matched_result = pd.concat([treated_matches, control_matches])
        matched_result['match_grade'] = grade
        if matched_result['match_id'].nunique() < 20:
            print(f"  Skipping Grade {grade} | LEA {lea}: too few matched pairs ({matched_result['match_id'].nunique()})")
            continue

        matched_dfs.append(matched_result)

        print(f"  Grade {grade} | LEA {lea} | Matches: {len(matched_result)}")

# Final combined match set
all_matches = pd.concat(matched_dfs, axis=0).reset_index(drop=True)


all_matches_trimmed = all_matches[(all_matches['pscore'] >= 0.15) & (all_matches['pscore'] <= 0.85)]

counts = all_matches_trimmed["match_id"].value_counts()

# Keep only rows where matchid appears more than once
pairs = all_matches_trimmed[all_matches_trimmed["match_id"].isin(counts[counts > 1].index)]
# Out:
# Processing grade 4...
#   Grade 4 | LEA 970 | Matches: 278
#   Grade 4 | LEA 491 | Matches: 416
#   Grade 4 | LEA 020 | Matches: 524
#   Grade 4 | LEA 990 | Matches: 524
#   Grade 4 | LEA 190 | Matches: 830
#   Grade 4 | LEA 862 | Matches: 68
#   Grade 4 | LEA 790 | Matches: 922
#   Grade 4 | LEA 410 | Matches: 1944
#   Grade 4 | LEA 110 | Matches: 442
#   Grade 4 | LEA 590 | Matches: 410
#   Grade 4 | LEA 111 | Matches: 132
#   Grade 4 | LEA 030 | Matches: 94
#   Grade 4 | LEA 290 | Matches: 682
#   Grade 4 | LEA 300 | Matches: 516
#   Grade 4 | LEA 291 | Matches: 172
#   Grade 4 | LEA 760 | Matches: 550
#   Grade 4 | LEA 620 | Matches: 136
#   Grade 4 | LEA 340 | Matches: 360
#   Grade 4 | LEA 360 | Matches: 278
#   Grade 4 | LEA 250 | Matches: 798
#   Grade 4 | LEA 995 | Matches: 88
#   Grade 4 | LEA 270 | Matches: 82
#   Grade 4 | LEA 490 | Matches: 618
#   Grade 4 | LEA 800 | Matches: 668
#   Grade 4 | LEA 180 | Matches: 1368
#   Grade 4 | LEA 740 | Matches: 1404
#   Grade 4 | LEA 070 | Matches: 224
#   Grade 4 | LEA 320 | Matches: 518
#   Grade 4 | LEA 130 | Matches: 532
#   Grade 4 | LEA 840 | Matches: 268
#   Grade 4 | LEA 681 | Matches: 852
#   Skipping Grade 4 | LEA 32L: too few matched pairs (6)
#   Grade 4 | LEA 900 | Matches: 3370
#   Grade 4 | LEA 650 | Matches: 412
#   Grade 4 | LEA 710 | Matches: 508
#   Grade 4 | LEA 600 | Matches: 994
#   Grade 4 | LEA 160 | Matches: 318
#   Grade 4 | LEA 181 | Matches: 244
#   Grade 4 | LEA 470 | Matches: 86
#   Grade 4 | LEA 100 | Matches: 660
#   Grade 4 | LEA 870 | Matches: 50
#   Grade 4 | LEA 770 | Matches: 108
#   Grade 4 | LEA 830 | Matches: 122
#   Grade 4 | LEA 090 | Matches: 210
#   Skipping Grade 4 | LEA 422: too few matched pairs (4)
#   Grade 4 | LEA 440 | Matches: 192
#   Grade 4 | LEA 960 | Matches: 1028
#   Skipping Grade 4 | LEA 210: too few matched pairs (5)
#   Grade 4 | LEA 260 | Matches: 954
#   Grade 4 | LEA 780 | Matches: 460
#   Grade 4 | LEA 280 | Matches: 366
#   Grade 4 | LEA 820 | Matches: 382
#   Grade 4 | LEA 310 | Matches: 502
#   Grade 4 | LEA 230 | Matches: 658
#   Grade 4 | LEA 810 | Matches: 376
#   Grade 4 | LEA 120 | Matches: 354
#   Grade 4 | LEA 010 | Matches: 1278
#   Grade 4 | LEA 530 | Matches: 916
#   Grade 4 | LEA 630 | Matches: 258
#   Grade 4 | LEA 670 | Matches: 556
#   Grade 4 | LEA 761 | Matches: 184
#   Grade 4 | LEA 540 | Matches: 218
#   Skipping Grade 4 | LEA 080: too few matched pairs (6)
#   Grade 4 | LEA 860 | Matches: 220
#   Grade 4 | LEA 861 | Matches: 40
#   Grade 4 | LEA 920 | Matches: 8052
#   Grade 4 | LEA 850 | Matches: 496
#   Grade 4 | LEA 050 | Matches: 246
#   Grade 4 | LEA 821 | Matches: 40
#   Skipping Grade 4 | LEA 420: too few matched pairs (9)
#   Grade 4 | LEA 430 | Matches: 318
#   Grade 4 | LEA 880 | Matches: 112
#   Grade 4 | LEA 680 | Matches: 178
#   Grade 4 | LEA 140 | Matches: 760
#   Grade 4 | LEA 750 | Matches: 40
#   Grade 4 | LEA 060 | Matches: 58
#   Skipping Grade 4 | LEA 660: too few matched pairs (5)
#   Grade 4 | LEA 550 | Matches: 564
#   Skipping Grade 4 | LEA 690: too few matched pairs (12)
#   Skipping Grade 4 | LEA 421: too few matched pairs (11)
#   Grade 4 | LEA 610 | Matches: 156
#   Grade 4 | LEA 350 | Matches: 106
#   Grade 4 | LEA 240 | Matches: 276
#   Grade 4 | LEA 330 | Matches: 146
#   Skipping Grade 4 | LEA 370: too few matched pairs (4)
#   Grade 4 | LEA 241 | Matches: 44
#   Skipping Grade 4 | LEA 150: too few matched pairs (6)
#   Skipping Grade 4 | LEA 380: too few matched pairs (14)
#   Skipping Grade 4 | LEA 890: too few matched pairs (3)
#   Grade 4 | LEA 720 | Matches: 58
#   Grade 4 | LEA 182 | Matches: 184
#   Skipping Grade 4 | LEA 132: too few matched pairs (15)
#   Grade 4 | LEA 980 | Matches: 358
#   Skipping Grade 4 | LEA 930: too few matched pairs (13)
#   Grade 4 | LEA 170 | Matches: 78
#   Grade 4 | LEA 730 | Matches: 168
#   Skipping Grade 4 | LEA 940: too few matched pairs (6)
#   Grade 4 | LEA 200 | Matches: 68
#   Grade 4 | LEA 400 | Matches: 62
#   Grade 4 | LEA 640 | Matches: 360
#   Grade 4 | LEA 510 | Matches: 736
#   Grade 4 | LEA 450 | Matches: 226
#   Grade 4 | LEA 910 | Matches: 154
#   Grade 4 | LEA 580 | Matches: 58
#   Grade 4 | LEA 560 | Matches: 166
#   Grade 4 | LEA 040 | Matches: 86
#   Skipping Grade 4 | LEA 700: too few matched pairs (18)
#   Grade 4 | LEA 390 | Matches: 240
#   Grade 4 | LEA 500 | Matches: 174
#   Skipping Grade 4 | LEA 480: too few matched pairs (1)
#   Grade 4 | LEA 950 | Matches: 108
#   Grade 4 | LEA 570 | Matches: 46
#   Skipping Grade 4 | LEA 292: too few matched pairs (14)
#   Skipping Grade 4 | LEA 92F: too few matched pairs (16)
#   Skipping Grade 4 | LEA 520: too few matched pairs (1)
#   Skipping Grade 4 | LEA 69A: too few matched pairs (1)
#   Skipping Grade 4 | LEA 92G: too few matched pairs (8)
#   Skipping Grade 4 | LEA 460: too few matched pairs (16)
#   Skipping Grade 4 | LEA 36C: too few matched pairs (5)
#
# Processing grade 5...
#   Grade 5 | LEA 970 | Matches: 200
#   Grade 5 | LEA 790 | Matches: 280
#   Grade 5 | LEA 110 | Matches: 222
#   Grade 5 | LEA 410 | Matches: 988
#   Grade 5 | LEA 570 | Matches: 66
#   Grade 5 | LEA 350 | Matches: 112
#   Skipping Grade 5 | LEA 111: too few matched pairs (10)
#   Skipping Grade 5 | LEA 030: too few matched pairs (10)
#   Grade 5 | LEA 290 | Matches: 202
#   Grade 5 | LEA 250 | Matches: 118
#   Grade 5 | LEA 995 | Matches: 62
#   Grade 5 | LEA 700 | Matches: 54
#   Skipping Grade 5 | LEA 270: too few matched pairs (15)
#   Grade 5 | LEA 590 | Matches: 102
#   Grade 5 | LEA 800 | Matches: 370
#   Grade 5 | LEA 490 | Matches: 338
#   Grade 5 | LEA 550 | Matches: 128
#   Grade 5 | LEA 680 | Matches: 82
#   Grade 5 | LEA 320 | Matches: 278
#   Grade 5 | LEA 990 | Matches: 54
#   Grade 5 | LEA 300 | Matches: 116
#   Grade 5 | LEA 130 | Matches: 336
#   Grade 5 | LEA 780 | Matches: 266
#   Grade 5 | LEA 650 | Matches: 274
#   Grade 5 | LEA 900 | Matches: 778
#   Grade 5 | LEA 840 | Matches: 144
#   Grade 5 | LEA 600 | Matches: 506
#   Skipping Grade 5 | LEA 770: too few matched pairs (16)
#   Grade 5 | LEA 090 | Matches: 88
#   Grade 5 | LEA 960 | Matches: 212
#   Grade 5 | LEA 440 | Matches: 112
#   Grade 5 | LEA 540 | Matches: 126
#   Grade 5 | LEA 260 | Matches: 508
#   Grade 5 | LEA 670 | Matches: 258
#   Grade 5 | LEA 430 | Matches: 210
#   Grade 5 | LEA 820 | Matches: 246
#   Grade 5 | LEA 730 | Matches: 54
#   Grade 5 | LEA 230 | Matches: 292
#   Grade 5 | LEA 360 | Matches: 134
#   Skipping Grade 5 | LEA 92G: too few matched pairs (8)
#   Grade 5 | LEA 530 | Matches: 248
#   Grade 5 | LEA 630 | Matches: 112
#   Grade 5 | LEA 160 | Matches: 104
#   Skipping Grade 5 | LEA 761: too few matched pairs (10)
#   Grade 5 | LEA 880 | Matches: 56
#   Grade 5 | LEA 760 | Matches: 190
#   Skipping Grade 5 | LEA 080: too few matched pairs (9)
#   Grade 5 | LEA 860 | Matches: 42
#   Skipping Grade 5 | LEA 620: too few matched pairs (12)
#   Grade 5 | LEA 340 | Matches: 346
#   Grade 5 | LEA 850 | Matches: 122
#   Skipping Grade 5 | LEA 821: too few matched pairs (13)
#   Grade 5 | LEA 470 | Matches: 56
#   Skipping Grade 5 | LEA 862: too few matched pairs (14)
#   Grade 5 | LEA 810 | Matches: 160
#   Grade 5 | LEA 450 | Matches: 182
#   Grade 5 | LEA 120 | Matches: 292
#   Grade 5 | LEA 140 | Matches: 386
#   Skipping Grade 5 | LEA 750: too few matched pairs (19)
#   Skipping Grade 5 | LEA 870: too few matched pairs (9)
#   Skipping Grade 5 | LEA 060: too few matched pairs (13)
#   Grade 5 | LEA 181 | Matches: 76
#   Skipping Grade 5 | LEA 690: too few matched pairs (4)
#   Skipping Grade 5 | LEA 421: too few matched pairs (3)
#   Grade 5 | LEA 710 | Matches: 132
#   Grade 5 | LEA 240 | Matches: 114
#   Grade 5 | LEA 100 | Matches: 224
#   Skipping Grade 5 | LEA 330: too few matched pairs (16)
#   Grade 5 | LEA 980 | Matches: 102
#   Skipping Grade 5 | LEA 370: too few matched pairs (1)
#   Grade 5 | LEA 280 | Matches: 94
#   Grade 5 | LEA 740 | Matches: 292
#   Skipping Grade 5 | LEA 241: too few matched pairs (11)
#   Skipping Grade 5 | LEA 150: too few matched pairs (5)
#   Skipping Grade 5 | LEA 220: too few matched pairs (15)
#   Skipping Grade 5 | LEA 380: too few matched pairs (13)
#   Skipping Grade 5 | LEA 890: too few matched pairs (2)
#   Skipping Grade 5 | LEA 720: too few matched pairs (5)
#   Grade 5 | LEA 180 | Matches: 320
#   Skipping Grade 5 | LEA 930: too few matched pairs (9)
#   Grade 5 | LEA 070 | Matches: 128
#   Skipping Grade 5 | LEA 291: too few matched pairs (14)
#   Grade 5 | LEA 050 | Matches: 58
#   Skipping Grade 5 | LEA 460: too few matched pairs (10)
#   Grade 5 | LEA 170 | Matches: 56
#   Grade 5 | LEA 190 | Matches: 132
#   Skipping Grade 5 | LEA 200: too few matched pairs (13)
#   Skipping Grade 5 | LEA 400: too few matched pairs (16)
#   Grade 5 | LEA 010 | Matches: 292
#   Grade 5 | LEA 640 | Matches: 186
#   Grade 5 | LEA 491 | Matches: 58
#   Grade 5 | LEA 020 | Matches: 100
#   Skipping Grade 5 | LEA 182: too few matched pairs (18)
#   Grade 5 | LEA 510 | Matches: 348
#   Grade 5 | LEA 910 | Matches: 82
#   Skipping Grade 5 | LEA 580: too few matched pairs (4)
#   Skipping Grade 5 | LEA 420: too few matched pairs (12)
#   Skipping Grade 5 | LEA 040: too few matched pairs (18)
#   Grade 5 | LEA 310 | Matches: 96
#   Grade 5 | LEA 920 | Matches: 1056
#   Grade 5 | LEA 830 | Matches: 72
#   Grade 5 | LEA 390 | Matches: 88
#   Grade 5 | LEA 500 | Matches: 46
#   Skipping Grade 5 | LEA 520: too few matched pairs (4)
#   Skipping Grade 5 | LEA 861: too few matched pairs (6)
#   Skipping Grade 5 | LEA 950: too few matched pairs (19)
#   Grade 5 | LEA 681 | Matches: 362
#   Skipping Grade 5 | LEA 292: too few matched pairs (2)
#   Skipping Grade 5 | LEA 610: too few matched pairs (2)
#   Grade 5 | LEA 560 | Matches: 44
#   Skipping Grade 5 | LEA 132: too few matched pairs (13)
#   Skipping Grade 5 | LEA 210: too few matched pairs (1)
#
# Processing grade 6...
#   Grade 6 | LEA 410 | Matches: 1100
#   Grade 6 | LEA 970 | Matches: 76
#   Grade 6 | LEA 300 | Matches: 42
#   Grade 6 | LEA 790 | Matches: 178
#   Grade 6 | LEA 110 | Matches: 104
#   Grade 6 | LEA 450 | Matches: 74
#   Skipping Grade 6 | LEA 111: too few matched pairs (9)
#   Skipping Grade 6 | LEA 030: too few matched pairs (7)
#   Grade 6 | LEA 290 | Matches: 84
#   Grade 6 | LEA 250 | Matches: 72
#   Grade 6 | LEA 800 | Matches: 182
#   Skipping Grade 6 | LEA 995: too few matched pairs (5)
#   Skipping Grade 6 | LEA 270: too few matched pairs (9)
#   Grade 6 | LEA 590 | Matches: 42
#   Grade 6 | LEA 490 | Matches: 232
#   Grade 6 | LEA 070 | Matches: 132
#   Grade 6 | LEA 740 | Matches: 154
#   Grade 6 | LEA 320 | Matches: 170
#   Skipping Grade 6 | LEA 990: too few matched pairs (18)
#   Grade 6 | LEA 130 | Matches: 564
#   Grade 6 | LEA 340 | Matches: 210
#   Grade 6 | LEA 681 | Matches: 238
#   Grade 6 | LEA 650 | Matches: 144
#   Grade 6 | LEA 240 | Matches: 84
#   Grade 6 | LEA 840 | Matches: 74
#   Grade 6 | LEA 600 | Matches: 122
#   Grade 6 | LEA 900 | Matches: 452
#   Skipping Grade 6 | LEA 491: too few matched pairs (9)
#   Skipping Grade 6 | LEA 870: too few matched pairs (6)
#   Skipping Grade 6 | LEA 770: too few matched pairs (15)
#   Skipping Grade 6 | LEA 090: too few matched pairs (8)
#   Grade 6 | LEA 440 | Matches: 66
#   Grade 6 | LEA 960 | Matches: 100
#   Skipping Grade 6 | LEA 210: too few matched pairs (3)
#   Grade 6 | LEA 640 | Matches: 124
#   Grade 6 | LEA 260 | Matches: 144
#   Grade 6 | LEA 100 | Matches: 154
#   Grade 6 | LEA 530 | Matches: 238
#   Grade 6 | LEA 820 | Matches: 146
#   Grade 6 | LEA 230 | Matches: 56
#   Grade 6 | LEA 630 | Matches: 98
#   Skipping Grade 6 | LEA 160: too few matched pairs (18)
#   Grade 6 | LEA 761 | Matches: 42
#   Grade 6 | LEA 540 | Matches: 136
#   Skipping Grade 6 | LEA 880: too few matched pairs (17)
#   Grade 6 | LEA 190 | Matches: 100
#   Grade 6 | LEA 760 | Matches: 120
#   Skipping Grade 6 | LEA 860: too few matched pairs (7)
#   Skipping Grade 6 | LEA 620: too few matched pairs (5)
#   Skipping Grade 6 | LEA 821: too few matched pairs (7)
#   Skipping Grade 6 | LEA 080: too few matched pairs (5)
#   Skipping Grade 6 | LEA 470: too few matched pairs (18)
#   Grade 6 | LEA 010 | Matches: 294
#   Grade 6 | LEA 680 | Matches: 50
#   Grade 6 | LEA 810 | Matches: 98
#   Grade 6 | LEA 140 | Matches: 192
#   Grade 6 | LEA 360 | Matches: 242
#   Grade 6 | LEA 180 | Matches: 166
#   Grade 6 | LEA 120 | Matches: 200
#   Skipping Grade 6 | LEA 690: too few matched pairs (5)
#   Skipping Grade 6 | LEA 421: too few matched pairs (7)
#   Skipping Grade 6 | LEA 280: too few matched pairs (14)
#   Skipping Grade 6 | LEA 420: too few matched pairs (8)
#   Grade 6 | LEA 610 | Matches: 40
#   Grade 6 | LEA 710 | Matches: 92
#   Grade 6 | LEA 350 | Matches: 90
#   Skipping Grade 6 | LEA 910: too few matched pairs (15)
#   Skipping Grade 6 | LEA 330: too few matched pairs (9)
#   Skipping Grade 6 | LEA 150: too few matched pairs (11)
#   Skipping Grade 6 | LEA 220: too few matched pairs (6)
#   Skipping Grade 6 | LEA 200: too few matched pairs (7)
#   Skipping Grade 6 | LEA 380: too few matched pairs (3)
#   Skipping Grade 6 | LEA 720: too few matched pairs (2)
#   Skipping Grade 6 | LEA 980: too few matched pairs (18)
#   Skipping Grade 6 | LEA 181: too few matched pairs (12)
#   Skipping Grade 6 | LEA 291: too few matched pairs (17)
#   Grade 6 | LEA 050 | Matches: 44
#   Skipping Grade 6 | LEA 170: too few matched pairs (9)
#   Skipping Grade 6 | LEA 730: too few matched pairs (11)
#   Skipping Grade 6 | LEA 400: too few matched pairs (8)
#   Grade 6 | LEA 550 | Matches: 98
#   Grade 6 | LEA 780 | Matches: 78
#   Grade 6 | LEA 510 | Matches: 50
#   Skipping Grade 6 | LEA 560: too few matched pairs (4)
#   Skipping Grade 6 | LEA 040: too few matched pairs (16)
#   Grade 6 | LEA 310 | Matches: 42
#   Skipping Grade 6 | LEA 700: too few matched pairs (4)
#   Skipping Grade 6 | LEA 830: too few matched pairs (18)
#   Grade 6 | LEA 020 | Matches: 60
#   Skipping Grade 6 | LEA 570: too few matched pairs (12)
#   Grade 6 | LEA 390 | Matches: 52
#   Grade 6 | LEA 430 | Matches: 150
#   Skipping Grade 6 | LEA 500: too few matched pairs (15)
#   Grade 6 | LEA 850 | Matches: 46
#   Grade 6 | LEA 670 | Matches: 128
#   Skipping Grade 6 | LEA 520: too few matched pairs (2)
#   Skipping Grade 6 | LEA 861: too few matched pairs (4)
#   Skipping Grade 6 | LEA 480: too few matched pairs (8)
#   Skipping Grade 6 | LEA 950: too few matched pairs (11)
#   Skipping Grade 6 | LEA 241: too few matched pairs (4)
#   Grade 6 | LEA 920 | Matches: 188
#   Skipping Grade 6 | LEA 930: too few matched pairs (6)
#   Skipping Grade 6 | LEA 750: too few matched pairs (5)
#   Skipping Grade 6 | LEA 460: too few matched pairs (4)
#   Skipping Grade 6 | LEA 182: too few matched pairs (18)
#   Skipping Grade 6 | LEA 32L: too few matched pairs (4)
#   Skipping Grade 6 | LEA 370: too few matched pairs (5)
#   Skipping Grade 6 | LEA 69A: too few matched pairs (1)
#   Skipping Grade 6 | LEA 060: too few matched pairs (3)
#   Skipping Grade 6 | LEA 81B: too few matched pairs (5)
#
# Processing grade 7...
#   Grade 7 | LEA 970 | Matches: 68
#   Grade 7 | LEA 790 | Matches: 66
#   Grade 7 | LEA 110 | Matches: 68
#   Grade 7 | LEA 290 | Matches: 150
#   Skipping Grade 7 | LEA 950: too few matched pairs (10)
#   Skipping Grade 7 | LEA 995: too few matched pairs (3)
#   Skipping Grade 7 | LEA 270: too few matched pairs (1)
#   Grade 7 | LEA 490 | Matches: 54
#   Grade 7 | LEA 070 | Matches: 40
#   Grade 7 | LEA 320 | Matches: 70
#   Skipping Grade 7 | LEA 990: too few matched pairs (4)
#   Grade 7 | LEA 130 | Matches: 96
#   Grade 7 | LEA 650 | Matches: 78
#   Skipping Grade 7 | LEA 840: too few matched pairs (7)
#   Grade 7 | LEA 491 | Matches: 64
#   Grade 7 | LEA 900 | Matches: 430
#   Skipping Grade 7 | LEA 770: too few matched pairs (10)
#   Skipping Grade 7 | LEA 440: too few matched pairs (10)
#   Grade 7 | LEA 960 | Matches: 70
#   Skipping Grade 7 | LEA 450: too few matched pairs (19)
#   Skipping Grade 7 | LEA 550: too few matched pairs (17)
#   Grade 7 | LEA 260 | Matches: 202
#   Skipping Grade 7 | LEA 820: too few matched pairs (14)
#   Grade 7 | LEA 530 | Matches: 60
#   Grade 7 | LEA 430 | Matches: 78
#   Skipping Grade 7 | LEA 160: too few matched pairs (9)
#   Grade 7 | LEA 540 | Matches: 42
#   Skipping Grade 7 | LEA 750: too few matched pairs (4)
#   Grade 7 | LEA 760 | Matches: 76
#   Grade 7 | LEA 340 | Matches: 46
#   Skipping Grade 7 | LEA 850: too few matched pairs (16)
#   Skipping Grade 7 | LEA 470: too few matched pairs (12)
#   Skipping Grade 7 | LEA 862: too few matched pairs (5)
#   Skipping Grade 7 | LEA 880: too few matched pairs (8)
#   Skipping Grade 7 | LEA 680: too few matched pairs (17)
#   Grade 7 | LEA 010 | Matches: 100
#   Skipping Grade 7 | LEA 810: too few matched pairs (13)
#   Grade 7 | LEA 140 | Matches: 122
#   Skipping Grade 7 | LEA 060: too few matched pairs (2)
#   Grade 7 | LEA 120 | Matches: 106
#   Grade 7 | LEA 710 | Matches: 66
#   Grade 7 | LEA 350 | Matches: 40
#   Grade 7 | LEA 240 | Matches: 44
#   Skipping Grade 7 | LEA 330: too few matched pairs (4)
#   Skipping Grade 7 | LEA 241: too few matched pairs (1)
#   Skipping Grade 7 | LEA 380: too few matched pairs (2)
#   Skipping Grade 7 | LEA 720: too few matched pairs (1)
#   Grade 7 | LEA 180 | Matches: 82
#   Skipping Grade 7 | LEA 132: too few matched pairs (17)
#   Skipping Grade 7 | LEA 360: too few matched pairs (17)
#   Skipping Grade 7 | LEA 460: too few matched pairs (8)
#   Skipping Grade 7 | LEA 170: too few matched pairs (3)
#   Skipping Grade 7 | LEA 730: too few matched pairs (4)
#   Grade 7 | LEA 190 | Matches: 48
#   Grade 7 | LEA 740 | Matches: 70
#   Skipping Grade 7 | LEA 200: too few matched pairs (3)
#   Grade 7 | LEA 410 | Matches: 502
#   Grade 7 | LEA 780 | Matches: 54
#   Skipping Grade 7 | LEA 040: too few matched pairs (11)
#   Skipping Grade 7 | LEA 310: too few matched pairs (10)
#   Skipping Grade 7 | LEA 100: too few matched pairs (14)
#   Grade 7 | LEA 800 | Matches: 46
#   Skipping Grade 7 | LEA 500: too few matched pairs (8)
#   Grade 7 | LEA 670 | Matches: 46
#   Skipping Grade 7 | LEA 590: too few matched pairs (5)
#   Grade 7 | LEA 681 | Matches: 58
#   Skipping Grade 7 | LEA 292: too few matched pairs (4)
#   Grade 7 | LEA 920 | Matches: 102
#   Skipping Grade 7 | LEA 570: too few matched pairs (6)
#   Skipping Grade 7 | LEA 940: too few matched pairs (2)
#   Skipping Grade 7 | LEA 300: too few matched pairs (14)
#   Skipping Grade 7 | LEA 370: too few matched pairs (16)
#   Grade 7 | LEA 630 | Matches: 54
#   Skipping Grade 7 | LEA 980: too few matched pairs (3)
#   Skipping Grade 7 | LEA 830: too few matched pairs (3)
#   Skipping Grade 7 | LEA 250: too few matched pairs (11)
#   Skipping Grade 7 | LEA 111: too few matched pairs (13)
#   Skipping Grade 7 | LEA 050: too few matched pairs (4)
#   Skipping Grade 7 | LEA 280: too few matched pairs (2)
#   Skipping Grade 7 | LEA 390: too few matched pairs (7)
#   Grade 7 | LEA 510 | Matches: 46
#   Skipping Grade 7 | LEA 36C: too few matched pairs (2)
#   Skipping Grade 7 | LEA 600: too few matched pairs (4)
#   Skipping Grade 7 | LEA 860: too few matched pairs (2)
#   Skipping Grade 7 | LEA 910: too few matched pairs (1)
#   Skipping Grade 7 | LEA 182: too few matched pairs (4)
#   Skipping Grade 7 | LEA 230: too few matched pairs (2)
#   Skipping Grade 7 | LEA 291: too few matched pairs (1)
#
# Processing grade 8...
#   Skipping Grade 8 | LEA 970: too few matched pairs (14)
#   Grade 8 | LEA 790 | Matches: 54
#   Skipping Grade 8 | LEA 110: too few matched pairs (18)
#   Grade 8 | LEA 290 | Matches: 138
#   Skipping Grade 8 | LEA 590: too few matched pairs (7)
#   Skipping Grade 8 | LEA 490: too few matched pairs (19)
#   Grade 8 | LEA 070 | Matches: 44
#   Grade 8 | LEA 320 | Matches: 46
#   Grade 8 | LEA 130 | Matches: 56
#   Skipping Grade 8 | LEA 840: too few matched pairs (13)
#   Skipping Grade 8 | LEA 870: too few matched pairs (1)
#   Skipping Grade 8 | LEA 630: too few matched pairs (17)
#   Skipping Grade 8 | LEA 960: too few matched pairs (17)
#   Skipping Grade 8 | LEA 440: too few matched pairs (5)
#   Skipping Grade 8 | LEA 720: too few matched pairs (9)
#   Grade 8 | LEA 260 | Matches: 210
#   Skipping Grade 8 | LEA 820: too few matched pairs (13)
#   Skipping Grade 8 | LEA 090: too few matched pairs (3)
#   Skipping Grade 8 | LEA 160: too few matched pairs (15)
#   Skipping Grade 8 | LEA 761: too few matched pairs (8)
#   Skipping Grade 8 | LEA 760: too few matched pairs (14)
#   Grade 8 | LEA 410 | Matches: 540
#   Skipping Grade 8 | LEA 340: too few matched pairs (14)
#   Skipping Grade 8 | LEA 420: too few matched pairs (9)
#   Skipping Grade 8 | LEA 470: too few matched pairs (15)
#   Skipping Grade 8 | LEA 810: too few matched pairs (5)
#   Grade 8 | LEA 140 | Matches: 70
#   Skipping Grade 8 | LEA 950: too few matched pairs (3)
#   Skipping Grade 8 | LEA 750: too few matched pairs (7)
#   Grade 8 | LEA 120 | Matches: 136
#   Skipping Grade 8 | LEA 350: too few matched pairs (5)
#   Skipping Grade 8 | LEA 240: too few matched pairs (19)
#   Skipping Grade 8 | LEA 330: too few matched pairs (5)
#   Skipping Grade 8 | LEA 370: too few matched pairs (19)
#   Grade 8 | LEA 900 | Matches: 122
#   Skipping Grade 8 | LEA 530: too few matched pairs (8)
#   Skipping Grade 8 | LEA 132: too few matched pairs (9)
#   Skipping Grade 8 | LEA 980: too few matched pairs (10)
#   Grade 8 | LEA 300 | Matches: 44
#   Skipping Grade 8 | LEA 460: too few matched pairs (3)
#   Skipping Grade 8 | LEA 740: too few matched pairs (15)
#   Skipping Grade 8 | LEA 940: too few matched pairs (3)
#   Grade 8 | LEA 780 | Matches: 76
#   Grade 8 | LEA 510 | Matches: 118
#   Skipping Grade 8 | LEA 100: too few matched pairs (7)
#   Skipping Grade 8 | LEA 800: too few matched pairs (6)
#   Skipping Grade 8 | LEA 050: too few matched pairs (6)
#   Grade 8 | LEA 920 | Matches: 90
#   Skipping Grade 8 | LEA 390: too few matched pairs (8)
#   Skipping Grade 8 | LEA 430: too few matched pairs (19)
#   Skipping Grade 8 | LEA 850: too few matched pairs (7)
#   Skipping Grade 8 | LEA 670: too few matched pairs (19)
#   Grade 8 | LEA 010 | Matches: 60
#   Skipping Grade 8 | LEA 190: too few matched pairs (16)
#   Grade 8 | LEA 650 | Matches: 48
#   Skipping Grade 8 | LEA 540: too few matched pairs (9)
#   Skipping Grade 8 | LEA 292: too few matched pairs (4)
#   Skipping Grade 8 | LEA 180: too few matched pairs (3)
#   Skipping Grade 8 | LEA 360: too few matched pairs (3)
#   Skipping Grade 8 | LEA 570: too few matched pairs (8)
#   Skipping Grade 8 | LEA 680: too few matched pairs (11)
#   Skipping Grade 8 | LEA 640: too few matched pairs (4)
#   Skipping Grade 8 | LEA 710: too few matched pairs (13)
#   Skipping Grade 8 | LEA 681: too few matched pairs (15)
#   Skipping Grade 8 | LEA 182: too few matched pairs (14)
#   Skipping Grade 8 | LEA 250: too few matched pairs (11)
#   Skipping Grade 8 | LEA 310: too few matched pairs (11)
#   Skipping Grade 8 | LEA 421: too few matched pairs (2)
#   Skipping Grade 8 | LEA 500: too few matched pairs (4)
#   Skipping Grade 8 | LEA 060: too few matched pairs (4)
#   Skipping Grade 8 | LEA 910: too few matched pairs (3)
#   Skipping Grade 8 | LEA 200: too few matched pairs (3)

# %%
pairs.to_csv("data/final/pairs.csv",index=False)
